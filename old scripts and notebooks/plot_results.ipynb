# %%
import numpy as np
import pickle
import glob
import matplotlib.pyplot as plt

# %%
def plot_results(files, runs):
    _, axs1 = plt.subplots(1, 3, figsize=(18, 5))
    _, axs2 = plt.subplots(1, 3, figsize=(18, 5))
    for file, run in zip(files, runs):
        with open(file, 'rb') as file:
            data = pickle.load(file)
            pressures = []
            corr = []
            corr_err = []
            sc = []
            dt = []
            rates = []
            for d in data:
                print(d)
                pressures.append(d['pressure'])
                corr.append(d['correlation'][0][1])
                corr_err.append(d['correlation_error'][0][1])
                sc.append(d['SC_max'])
                dt.append(d['SC_dt_max'])
                rates.append(np.mean(d['rate_total']))
            
            axs1[0].errorbar(pressures, corr, yerr=corr_err, label=run, marker='s')
            axs1[0].legend()
            axs1[0].set_xlabel('pressure')
            axs1[0].set_ylabel('correlation')

            axs1[1].plot(pressures, sc, label=run, marker='s')
            axs1[1].legend()
            axs1[1].set_xlabel('pressure')
            axs1[1].set_ylabel('spike contrast')

            #axs1[2].plot(pressures, dt, label=run, marker='s')
            #axs1[2].legend()
            #axs1[2].set_xlabel('pressure')
            #axs1[2].set_ylabel('dt_max spike contrast [s]')

            axs1[2].plot(pressures, rates, label=run, marker='s')
            axs1[2].legend()
            axs1[2].set_xlabel('pressure')
            axs1[2].set_ylabel('average firing rate')

            axs2[0].plot(pressures, corr/corr[0], label=run, marker='s')
            axs2[0].legend()
            axs2[0].set_xlabel('pressure')
            axs2[0].set_ylabel('norm correlation')

            axs2[1].plot(pressures, sc/sc[0], label=run, marker='s')
            axs2[1].legend()
            axs2[1].set_xlabel('pressure')
            axs2[1].set_ylabel('norm spike contrast')

            #axs2[2].plot(pressures, dt/dt[0], label=run, marker='s')
            #axs2[2].legend()
            #axs2[2].set_xlabel('pressure')
            #axs2[2].set_ylabel('dt_max spike contrast [s]')

            axs2[2].plot(pressures, rates/rates[0], label=run, marker='s')
            axs2[2].legend()
            axs2[2].set_xlabel('pressure')
            axs2[2].set_ylabel('average firing rate')

# %%
base_path = 'C:\\Users\\bow-lab\\Documents\\Code\\spike_train_analysis\\results_25286\\results_25286'

runs = ['A_1', 'B_1', 'A_2', 'B_2']

files = []

for run in runs:
    filename = f'{base_path}_{run}.pkl'
    files.append(filename)
    print(filename)
# Out:
# C:\Users\bow-lab\Documents\Code\spike_train_analysis\results_25286\results_25286_A_1.pkl
# C:\Users\bow-lab\Documents\Code\spike_train_analysis\results_25286\results_25286_B_1.pkl
# C:\Users\bow-lab\Documents\Code\spike_train_analysis\results_25286\results_25286_A_2.pkl
# C:\Users\bow-lab\Documents\Code\spike_train_analysis\results_25286\results_25286_B_2.pkl

# %%
plot_results(files, runs)
# Out:
# {'mode': 'minimal', 'pressure': 0.13, 'file_ID': 'chunk0', 'N_units': 65, 'N_samples': 5999964, 'T_total': 299.9982, 'sample_rate': 20000, 'rate_total': array([33.33333333, 66.66666667, 66.66666667, ..., 66.66666667,
#        66.66666667, 33.33333333]), 'time_rate_total': array([1.500000e-02, 1.650000e-02, 1.800000e-02, ..., 3.000090e+02,
#        3.000105e+02, 3.000120e+02]), 'correlation': [[61.65220608849168, 3.9545765352594775, 30.001923076923084, 4.505125208157813, 34.77710215202184]], 'SC_max': 0.10275547513200818, 'SC_dt_max': 0.4328761281083057}
# {'mode': 'minimal', 'pressure': 11.49, 'file_ID': 'chunk1', 'N_units': 65, 'N_samples': 6000162, 'T_total': 300.0081, 'sample_rate': 20000, 'rate_total': array([466.66666667, 433.33333333, 466.66666667, ..., 133.33333333,
#        100.        ,  66.66666667]), 'time_rate_total': array([1.500000e-02, 1.650000e-02, 1.800000e-02, ..., 3.000195e+02,
# ...

# %%
base_path = 'C:\\Users\\bow-lab\\Documents\\Code\\spike_train_analysis\\results_25237\\results_25327'

runs = ['A_1', 'B_1','A_2', 'B_2']

files = []

for run in runs:
    files.append(f'{base_path}_{run}.pkl')

# %%
plot_results(files, runs)
# Out:
# {'mode': 'minimal', 'pressure': 0.13, 'file_ID': 'chunk0', 'N_units': 186, 'N_samples': 6000147, 'T_total': 300.00735, 'sample_rate': 20000, 'rate_total': array([1566.66666667, 1766.66666667, 2033.33333333, ...,   66.66666667,
#          33.33333333,   33.33333333]), 'time_rate_total': array([1.500000e-02, 1.650000e-02, 1.800000e-02, ..., 3.000180e+02,
#        3.000195e+02, 3.000210e+02]), 'correlation': [[61.14446348916675, 3.7697277818409094, 28.377564661435635, 4.1750426252482375, 32.70711257476335]], 'SC_max': 0.16119960403809175, 'SC_dt_max': 0.32745491628777285}
# {'mode': 'minimal', 'pressure': 11.49, 'file_ID': 'chunk1', 'N_units': 186, 'N_samples': 6000583, 'T_total': 300.02915, 'sample_rate': 20000, 'rate_total': array([2633.33333333, 2700.        , 2500.        , ...,  366.66666667,
#         200.        ,   66.66666667]), 'time_rate_total': array([1.500000e-02, 1.650000e-02, 1.800000e-02, ..., 3.000405e+02,
# ...

# %%
base_path = 'C:\\Users\\bow-lab\\Documents\\Code\\spike_train_analysis\\results_25510\\results_'

runs = ['A_1', 'B_1','A_2', 'B_2']

files = []

for run in runs:
    files.append(f'{base_path}_{run}.pkl')

# %%
plot_results(files, runs)
# Out:
# {'mode': 'minimal', 'pressure': 0.04, 'file_ID': 'chunk0', 'N_units': 138, 'N_samples': 6000182, 'T_total': 300.0091, 'sample_rate': 20000, 'rate_total': array([866.66666667, 933.33333333, 966.66666667, ..., 133.33333333,
#         66.66666667,  33.33333333]), 'time_rate_total': array([1.500000e-02, 1.650000e-02, 1.800000e-02, ..., 3.000210e+02,
#        3.000225e+02, 3.000240e+02]), 'correlation': array([[25.75101252,  1.02617915,  4.09389976],
#        [17.88982525,  1.06652161,  3.73347492]]), 'correlation_error': array([[1.09519236, 0.02541507, 0.15633097],
#        [0.98039085, 0.03445728, 0.12495396]]), 'SC_max': 0.06465683905195653, 'SC_dt_max': 0.16297508346206452}
# {'mode': 'minimal', 'pressure': 10.38, 'file_ID': 'chunk1', 'N_units': 140, 'N_samples': 6000189, 'T_total': 300.00945, 'sample_rate': 20000, 'rate_total': array([1666.66666667, 1766.66666667, 1800.        , ...,  100.        ,
# ...
